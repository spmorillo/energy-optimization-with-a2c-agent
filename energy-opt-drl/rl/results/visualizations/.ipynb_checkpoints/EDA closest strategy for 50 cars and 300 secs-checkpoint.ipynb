# %%
# !ls
# Out:
#  A2C_closest_strategy.py	     edc_report.csv
#  closest_strategy_data.csv	     sdn_strategy_closest.py
# 'EDA closest strategy-Copy1.ipynb'   sdn_strategy_closest_txt_v1.py
# 'EDA closest strategy.ipynb'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
import seaborn as sns

# %%
df = pd.read_csv('closest_strategy_data_50cars_300seg.csv', delimiter=";")

# %%
df
# Out:
#        ap_id edc_id_0        edc_location_0  overall_std_u_0  max_std_u_0  \
# 0       ap_0    edc_0  (950.6207, 777.7721)              0.0          500
# 1       ap_1    edc_0  (950.6207, 777.7721)              0.0          500
# 2       ap_2    edc_0  (950.6207, 777.7721)              0.0          500
# 3       ap_3    edc_0  (950.6207, 777.7721)              0.0          500
# 4       ap_4    edc_0  (950.6207, 777.7721)              0.0          500
# ...      ...      ...                   ...              ...          ...
# 12931   ap_6    edc_0  (950.6207, 777.7721)            360.0          500
# 12932   ap_7    edc_0  (950.6207, 777.7721)            360.0          500
# 12933   ap_8    edc_0  (950.6207, 777.7721)            360.0          500
# 12934   ap_9    edc_0  (950.6207, 777.7721)            360.0          500
# 12935  ap_10    edc_0  (950.6207, 777.7721)            360.0          500
#
#        pue_0  power_demand_0  power_consumption_0  it_power_0  \
# 0        0.0        0.000000           -50.000000    0.000000
# 1        0.0        0.000000           -50.000000    0.000000
# 2        0.0        0.000000           -50.000000    0.000000
# 3        0.0        0.000000           -50.000000    0.000000
# 4        0.0        0.000000           -50.000000    0.000000
# ...      ...             ...                  ...         ...
# 12931    1.0      527.347252           377.347252  527.347252
# 12932    1.0      527.347252           377.347252  527.347252
# 12933    1.0      527.347252           377.347252  527.347252
# 12934    1.0      527.347252           377.347252  527.347252
# 12935    1.0      527.347252           377.347252  527.347252
#
#        cooling_power_0  power_generation_0  charging_power_0  energy_stored_0  \
# 0                    0                  50                 0       100.000000
# 1                    0                  50                 0       100.000000
# 2                    0                  50                 0       100.000000
# 3                    0                  50                 0       100.000000
# 4                    0                  50                 0       100.000000
# ...                ...                 ...               ...              ...
# 12931                0                  50              -100        91.697222
# 12932                0                  50              -100        91.697222
# 12933                0                  50              -100        91.697222
# 12934                0                  50              -100        91.697222
# 12935                0                  50              -100        91.697222
#
#        energy_capacity_0 edc_id_1          edc_location_1  overall_std_u_1  \
# 0                    100    edc_1  (1639.6117, 1482.3435)              0.0
# 1                    100    edc_1  (1639.6117, 1482.3435)              0.0
# 2                    100    edc_1  (1639.6117, 1482.3435)              0.0
# 3                    100    edc_1  (1639.6117, 1482.3435)              0.0
# 4                    100    edc_1  (1639.6117, 1482.3435)              0.0
# ...                  ...      ...                     ...              ...
# 12931                100    edc_1  (1639.6117, 1482.3435)            380.0
# 12932                100    edc_1  (1639.6117, 1482.3435)            380.0
# 12933                100    edc_1  (1639.6117, 1482.3435)            380.0
# 12934                100    edc_1  (1639.6117, 1482.3435)            380.0
# 12935                100    edc_1  (1639.6117, 1482.3435)            380.0
#
#        max_std_u_1  pue_1  power_demand_1  power_consumption_1  it_power_1  \
# 0              500    0.0        0.000000           -50.000000    0.000000
# 1              500    0.0        0.000000           -50.000000    0.000000
# 2              500    0.0        0.000000           -50.000000    0.000000
# 3              500    0.0        0.000000           -50.000000    0.000000
# 4              500    0.0        0.000000           -50.000000    0.000000
# ...            ...    ...             ...                  ...         ...
# 12931          500    1.0      536.291405           386.291405  536.291405
# 12932          500    1.0      536.291405           386.291405  536.291405
# 12933          500    1.0      536.291405           386.291405  536.291405
# 12934          500    1.0      536.291405           386.291405  536.291405
# 12935          500    1.0      536.291405           386.291405  536.291405
#
#        cooling_power_1  power_generation_1  charging_power_1  energy_stored_1  \
# 0                    0                  50                 0            100.0
# 1                    0                  50                 0            100.0
# 2                    0                  50                 0            100.0
# 3                    0                  50                 0            100.0
# 4                    0                  50                 0            100.0
# ...                ...                 ...               ...              ...
# 12931                0                  50              -100             91.8
# 12932                0                  50              -100             91.8
# 12933                0                  50              -100             91.8
# 12934                0                  50              -100             91.8
# 12935                0                  50              -100             91.8
#
#        energy_capacity_1 edc_id_2         edc_location_2  overall_std_u_2  \
# 0                    100    edc_2  (802.2772, 2478.5847)              0.0
# 1                    100    edc_2  (802.2772, 2478.5847)              0.0
# 2                    100    edc_2  (802.2772, 2478.5847)              0.0
# 3                    100    edc_2  (802.2772, 2478.5847)              0.0
# 4                    100    edc_2  (802.2772, 2478.5847)              0.0
# ...                  ...      ...                    ...              ...
# 12931                100    edc_2  (802.2772, 2478.5847)            180.0
# 12932                100    edc_2  (802.2772, 2478.5847)            180.0
# 12933                100    edc_2  (802.2772, 2478.5847)            180.0
# 12934                100    edc_2  (802.2772, 2478.5847)            180.0
# 12935                100    edc_2  (802.2772, 2478.5847)            180.0
#
#        max_std_u_2  pue_2  power_demand_2  power_consumption_2  it_power_2  \
# 0              500    0.0        0.000000           -50.000000    0.000000
# 1              500    0.0        0.000000           -50.000000    0.000000
# 2              500    0.0        0.000000           -50.000000    0.000000
# 3              500    0.0        0.000000           -50.000000    0.000000
# 4              500    0.0        0.000000           -50.000000    0.000000
# ...            ...    ...             ...                  ...         ...
# 12931          500    1.0      497.360474           347.360474  497.360474
# 12932          500    1.0      497.360474           347.360474  497.360474
# 12933          500    1.0      497.360474           347.360474  497.360474
# 12934          500    1.0      497.360474           347.360474  497.360474
# 12935          500    1.0      497.360474           347.360474  497.360474
#
#        cooling_power_2  power_generation_2  charging_power_2  energy_stored_2  \
# 0                    0                  50                 0       100.000000
# 1                    0                  50                 0       100.000000
# 2                    0                  50                 0       100.000000
# 3                    0                  50                 0       100.000000
# 4                    0                  50                 0       100.000000
# ...                ...                 ...               ...              ...
# 12931                0                  50              -100        91.697222
# 12932                0                  50              -100        91.697222
# 12933                0                  50              -100        91.697222
# 12934                0                  50              -100        91.697222
# 12935                0                  50              -100        91.697222
#
#        energy_capacity_2  edc_distance_0  edc_distance_1  edc_distance_2  \
# 0                    100      369.133502     1133.652453     1320.622651
# 1                    100      400.047844     1700.704329     2060.252671
# 2                    100      613.067125     1184.287126     1329.256048
# 3                    100      627.531664     1159.676551     1899.352437
# 4                    100      299.587171      686.840512     1512.449018
# ...                  ...             ...             ...             ...
# 12931                100      685.185692     1069.088510     2186.212050
# 12932                100      400.383513     1191.755001     1667.910912
# 12933                100      423.268899     1407.665266     1984.784647
# 12934                100      573.842145      780.349062     1020.882641
# 12935                100      497.648939      742.635981     1723.942853
#
#       action
# 0      edc_1
# 1      edc_2
# 2      edc_0
# 3      edc_2
# 4      edc_0
# ...      ...
# 12931  edc_0
# 12932  edc_1
# 12933  edc_0
# 12934  edc_1
# 12935  edc_1
#
# [12936 rows x 44 columns]

# %%
df.action.value_counts()
# Out:
# edc_0    4704
# edc_1    4704
# edc_2    3528
# Name: action, dtype: int64

# %%
df.dtypes
# Out:
# ap_id                   object
# edc_id_0                object
# edc_location_0          object
# overall_std_u_0        float64
# max_std_u_0              int64
# pue_0                  float64
# power_demand_0         float64
# power_consumption_0    float64
# it_power_0             float64
# cooling_power_0          int64
# power_generation_0       int64
# charging_power_0         int64
# energy_stored_0        float64
# energy_capacity_0        int64
# edc_id_1                object
# edc_location_1          object
# overall_std_u_1        float64
# max_std_u_1              int64
# pue_1                  float64
# power_demand_1         float64
# power_consumption_1    float64
# it_power_1             float64
# cooling_power_1          int64
# power_generation_1       int64
# charging_power_1         int64
# energy_stored_1        float64
# energy_capacity_1        int64
# edc_id_2                object
# edc_location_2          object
# overall_std_u_2        float64
# max_std_u_2              int64
# pue_2                  float64
# power_demand_2         float64
# power_consumption_2    float64
# it_power_2             float64
# cooling_power_2          int64
# power_generation_2       int64
# charging_power_2         int64
# energy_stored_2        float64
# energy_capacity_2        int64
# edc_distance_0         float64
# edc_distance_1         float64
# edc_distance_2         float64
# action                  object
# dtype: object

# %%
df_0 = df.iloc[10:,] # copy() # [df.ap_id=="ap_0"]
df_0_0 = df_0[[col for col in df_0.columns if "_0" in col]]
for col in df_0_0.select_dtypes(include=np.number).columns:
    df_0_0.plot(y=col)

# %%
sns.set()
plt.rcParams['figure.figsize']=(10,10)
df_0.plot(y=[col for col in df.columns if "edc_distance" in col])

# %% [markdown]
# Important columns:
# - overall_std_u_0, overall_std_u_1, overal_std_u_2 -> scale to max_std_u_(0,1,2)
# - power_consumption_0, power_consumption_1, power_consumption_2 -> min_max w/o firt timestamp (for now)
# - edc_distance_0, edc_distance_1, edc_distance_2 -> min_max w/o first timestamp
# - action -> label encoding
#
# Possible columns
# - power_demand_0, power_demand_1, power_demand_2
# - it_power_0, it_power_1, it_power_2

# %%
df_tmp = df.iloc[11:].reset_index()
final_df = df_tmp[["ap_id",
               "overall_std_u_0", "overall_std_u_1", "overall_std_u_2",
               "max_std_u_0", "max_std_u_1", "max_std_u_2",
               "power_consumption_0", "power_consumption_1", "power_consumption_2",
               "edc_distance_0", "edc_distance_1", "edc_distance_2",
               "action"
               ]]

# %%
final_df
# Out:
#        ap_id  overall_std_u_0  overall_std_u_1  overall_std_u_2  max_std_u_0  \
# 0       ap_0              0.0              0.0              0.0          500
# 1       ap_1              0.0              0.0              0.0          500
# 2       ap_2              0.0              0.0              0.0          500
# 3       ap_3              0.0              0.0              0.0          500
# 4       ap_4              0.0              0.0              0.0          500
# ...      ...              ...              ...              ...          ...
# 12920   ap_6            360.0            380.0            180.0          500
# 12921   ap_7            360.0            380.0            180.0          500
# 12922   ap_8            360.0            380.0            180.0          500
# 12923   ap_9            360.0            380.0            180.0          500
# 12924  ap_10            360.0            380.0            180.0          500
#
#        max_std_u_1  max_std_u_2  power_consumption_0  power_consumption_1  \
# 0              500          500           291.393776           291.393776
# 1              500          500           291.393776           291.393776
# 2              500          500           291.393776           291.393776
# 3              500          500           291.393776           291.393776
# 4              500          500           291.393776           291.393776
# ...            ...          ...                  ...                  ...
# 12920          500          500           377.347252           386.291405
# 12921          500          500           377.347252           386.291405
# 12922          500          500           377.347252           386.291405
# 12923          500          500           377.347252           386.291405
# 12924          500          500           377.347252           386.291405
#
#        power_consumption_2  edc_distance_0  edc_distance_1  edc_distance_2  \
# 0               291.393776      369.133502     1133.652453     1320.622651
# 1               291.393776      400.047844     1700.704329     2060.252671
# 2               291.393776      613.067125     1184.287126     1329.256048
# 3               291.393776      627.531664     1159.676551     1899.352437
# 4               291.393776      299.587171      686.840512     1512.449018
# ...                    ...             ...             ...             ...
# 12920           347.360474      685.185692     1069.088510     2186.212050
# 12921           347.360474      400.383513     1191.755001     1667.910912
# 12922           347.360474      423.268899     1407.665266     1984.784647
# 12923           347.360474      573.842145      780.349062     1020.882641
# 12924           347.360474      497.648939      742.635981     1723.942853
#
#       action
# 0      edc_1
# 1      edc_2
# 2      edc_0
# 3      edc_2
# 4      edc_0
# ...      ...
# 12920  edc_0
# 12921  edc_1
# 12922  edc_0
# 12923  edc_1
# 12924  edc_1
#
# [12925 rows x 14 columns]

# %%
for col in final_df.select_dtypes(include=np.number).columns:
    final_df[final_df.ap_id=="ap_0"].plot(y=col)

# %%
def scale(data, min_, max_):
    return (data - min_) / (max_ - min_)

def scale_df(df_):
    df = df_.copy()
    for col in [col for col in final_df.columns if "edc_distance" in col]:
        df[col] = scale(df[col], 299.58, 2186.21)
    for col in [col for col in final_df.columns if "power_consumption" in col]:
        df[col] = scale(df[col], df["max_std_u_0"]/100*58, df["max_std_u_0"]/100*80)
    for col in [col for col in final_df.columns if "overall_std_u" in col]:
        df[col] = scale(df[col], 0, df["max_std_u_0"])
    return df

s_df = scale_df(final_df)
s_df
# Out:
#        ap_id  overall_std_u_0  overall_std_u_1  overall_std_u_2  max_std_u_0  \
# 0       ap_0             0.00             0.00             0.00          500
# 1       ap_1             0.00             0.00             0.00          500
# 2       ap_2             0.00             0.00             0.00          500
# 3       ap_3             0.00             0.00             0.00          500
# 4       ap_4             0.00             0.00             0.00          500
# ...      ...              ...              ...              ...          ...
# 12920   ap_6             0.72             0.76             0.36          500
# 12921   ap_7             0.72             0.76             0.36          500
# 12922   ap_8             0.72             0.76             0.36          500
# 12923   ap_9             0.72             0.76             0.36          500
# 12924  ap_10             0.72             0.76             0.36          500
#
#        max_std_u_1  max_std_u_2  power_consumption_0  power_consumption_1  \
# 0              500          500             0.012671             0.012671
# 1              500          500             0.012671             0.012671
# 2              500          500             0.012671             0.012671
# 3              500          500             0.012671             0.012671
# 4              500          500             0.012671             0.012671
# ...            ...          ...                  ...                  ...
# 12920          500          500             0.794066             0.875376
# 12921          500          500             0.794066             0.875376
# 12922          500          500             0.794066             0.875376
# 12923          500          500             0.794066             0.875376
# 12924          500          500             0.794066             0.875376
#
#        power_consumption_2  edc_distance_0  edc_distance_1  edc_distance_2  \
# 0                 0.012671        0.036867        0.442096        0.541199
# 1                 0.012671        0.053253        0.742660        0.933237
# 2                 0.012671        0.166162        0.468935        0.545775
# 3                 0.012671        0.173829        0.455890        0.847952
# 4                 0.012671        0.000004        0.205266        0.642876
# ...                    ...             ...             ...             ...
# 12920             0.521459        0.204389        0.407875        1.000001
# 12921             0.521459        0.053430        0.472893        0.725278
# 12922             0.521459        0.065561        0.587336        0.893235
# 12923             0.521459        0.145371        0.254830        0.382323
# 12924             0.521459        0.104986        0.234840        0.754977
#
#       action
# 0      edc_1
# 1      edc_2
# 2      edc_0
# 3      edc_2
# 4      edc_0
# ...      ...
# 12920  edc_0
# 12921  edc_1
# 12922  edc_0
# 12923  edc_1
# 12924  edc_1
#
# [12925 rows x 14 columns]

# %%
for col in s_df.select_dtypes(include=np.number).columns:
    s_df[final_df.ap_id=="ap_0"].plot(y=col)

# %%
data = final_df.values[:,1:]
obs = data[:,:-1]
actions = data[:,-1]

# %%
final_df
# Out:
#        ap_id  overall_std_u_0  overall_std_u_1  overall_std_u_2  max_std_u_0  \
# 0       ap_0              0.0              0.0              0.0          500
# 1       ap_1              0.0              0.0              0.0          500
# 2       ap_2              0.0              0.0              0.0          500
# 3       ap_3              0.0              0.0              0.0          500
# 4       ap_4              0.0              0.0              0.0          500
# ...      ...              ...              ...              ...          ...
# 12920   ap_6            360.0            380.0            180.0          500
# 12921   ap_7            360.0            380.0            180.0          500
# 12922   ap_8            360.0            380.0            180.0          500
# 12923   ap_9            360.0            380.0            180.0          500
# 12924  ap_10            360.0            380.0            180.0          500
#
#        max_std_u_1  max_std_u_2  power_consumption_0  power_consumption_1  \
# 0              500          500           291.393776           291.393776
# 1              500          500           291.393776           291.393776
# 2              500          500           291.393776           291.393776
# 3              500          500           291.393776           291.393776
# 4              500          500           291.393776           291.393776
# ...            ...          ...                  ...                  ...
# 12920          500          500           377.347252           386.291405
# 12921          500          500           377.347252           386.291405
# 12922          500          500           377.347252           386.291405
# 12923          500          500           377.347252           386.291405
# 12924          500          500           377.347252           386.291405
#
#        power_consumption_2  edc_distance_0  edc_distance_1  edc_distance_2  \
# 0               291.393776      369.133502     1133.652453     1320.622651
# 1               291.393776      400.047844     1700.704329     2060.252671
# 2               291.393776      613.067125     1184.287126     1329.256048
# 3               291.393776      627.531664     1159.676551     1899.352437
# 4               291.393776      299.587171      686.840512     1512.449018
# ...                    ...             ...             ...             ...
# 12920           347.360474      685.185692     1069.088510     2186.212050
# 12921           347.360474      400.383513     1191.755001     1667.910912
# 12922           347.360474      423.268899     1407.665266     1984.784647
# 12923           347.360474      573.842145      780.349062     1020.882641
# 12924           347.360474      497.648939      742.635981     1723.942853
#
#       action
# 0      edc_1
# 1      edc_2
# 2      edc_0
# 3      edc_2
# 4      edc_0
# ...      ...
# 12920  edc_0
# 12921  edc_1
# 12922  edc_0
# 12923  edc_1
# 12924  edc_1
#
# [12925 rows x 14 columns]

# %%
min([min(final_df[col]) for col in final_df.columns if "edc_distance" in col])
# Out:
# 299.5871710270652

# %%
max([max(final_df[col]) for col in final_df.columns if "edc_distance" in col])
# Out:
# 2186.2120501195

# %%
final_df.describe()
# Out:
#        overall_std_u_0  overall_std_u_1  overall_std_u_2  max_std_u_0  \
# count     12925.000000     12925.000000     12925.000000      12925.0
# mean        305.974468       340.425532       157.855319        500.0
# std          80.647647        93.689325        56.385334          0.0
# min           0.000000         0.000000         0.000000        500.0
# 25%         260.000000       300.000000       140.000000        500.0
# 50%         340.000000       380.000000       160.000000        500.0
# 75%         360.000000       400.000000       200.000000        500.0
# max         420.000000       460.000000       240.000000        500.0
#
#        max_std_u_1  max_std_u_2  power_consumption_0  power_consumption_1  \
# count      12925.0      12925.0         12925.000000         12925.000000
# mean         500.0        500.0           370.079112           380.979476
# std            0.0          0.0            14.790311            18.652908
# min          500.0        500.0           291.393776           291.393776
# 25%          500.0        500.0           366.783798           377.183922
# 50%          500.0        500.0           374.741982           386.291405
# 75%          500.0        500.0           377.347252           394.218513
# max          500.0        500.0           388.938919           399.444695
#
#        power_consumption_2  edc_distance_0  edc_distance_1  edc_distance_2
# count         12925.000000    12925.000000    12925.000000    12925.000000
# mean            332.518017      498.846111     1125.569956     1640.769215
# std              12.323588      121.138167      289.292819      351.036600
# min             291.393776      299.587171      686.840512     1020.882641
# 25%             330.446968      400.047844      780.349062     1329.256048
# 50%             333.025635      497.648939     1159.676551     1667.910912
# 75%             335.673149      613.067125     1324.614726     1984.784647
# max             352.586655      685.185692     1700.704329     2186.212050

# %%
s_df.describe().loc[['min','max'],:]
# Out:
#      overall_std_u_0  overall_std_u_1  overall_std_u_2  max_std_u_0  \
# min             0.00             0.00             0.00        500.0
# max             0.84             0.92             0.48        500.0
#
#      max_std_u_1  max_std_u_2  power_consumption_0  power_consumption_1  \
# min        500.0        500.0             0.012671             0.012671
# max        500.0        500.0             0.899445             0.994952
#
#      power_consumption_2  edc_distance_0  edc_distance_1  edc_distance_2
# min             0.012671        0.000004        0.205266        0.382323
# max             0.568970        0.204389        0.742660        1.000001

# %%
final_df[['edc_distance_0' ,'edc_distance_1', 'edc_distance_2']].head(100)
# Out:
#     edc_distance_0  edc_distance_1  edc_distance_2
# 0       369.133502     1133.652453     1320.622651
# 1       400.047844     1700.704329     2060.252671
# 2       613.067125     1184.287126     1329.256048
# 3       627.531664     1159.676551     1899.352437
# 4       299.587171      686.840512     1512.449018
# 5       597.610726     1324.614726     1342.795436
# 6       685.185692     1069.088510     2186.212050
# 7       400.383513     1191.755001     1667.910912
# 8       423.268899     1407.665266     1984.784647
# 9       573.842145      780.349062     1020.882641
# 10      497.648939      742.635981     1723.942853
# 11      369.133502     1133.652453     1320.622651
# 12      400.047844     1700.704329     2060.252671
# 13      613.067125     1184.287126     1329.256048
# 14      627.531664     1159.676551     1899.352437
# 15      299.587171      686.840512     1512.449018
# 16      597.610726     1324.614726     1342.795436
# 17      685.185692     1069.088510     2186.212050
# 18      400.383513     1191.755001     1667.910912
# 19      423.268899     1407.665266     1984.784647
# 20      573.842145      780.349062     1020.882641
# 21      497.648939      742.635981     1723.942853
# 22      369.133502     1133.652453     1320.622651
# 23      400.047844     1700.704329     2060.252671
# 24      613.067125     1184.287126     1329.256048
# 25      627.531664     1159.676551     1899.352437
# 26      299.587171      686.840512     1512.449018
# 27      597.610726     1324.614726     1342.795436
# 28      685.185692     1069.088510     2186.212050
# 29      400.383513     1191.755001     1667.910912
# 30      423.268899     1407.665266     1984.784647
# 31      573.842145      780.349062     1020.882641
# 32      497.648939      742.635981     1723.942853
# 33      369.133502     1133.652453     1320.622651
# 34      400.047844     1700.704329     2060.252671
# 35      613.067125     1184.287126     1329.256048
# 36      627.531664     1159.676551     1899.352437
# 37      299.587171      686.840512     1512.449018
# 38      597.610726     1324.614726     1342.795436
# 39      685.185692     1069.088510     2186.212050
# 40      400.383513     1191.755001     1667.910912
# 41      423.268899     1407.665266     1984.784647
# 42      573.842145      780.349062     1020.882641
# 43      497.648939      742.635981     1723.942853
# 44      369.133502     1133.652453     1320.622651
# 45      400.047844     1700.704329     2060.252671
# 46      613.067125     1184.287126     1329.256048
# 47      627.531664     1159.676551     1899.352437
# 48      299.587171      686.840512     1512.449018
# 49      597.610726     1324.614726     1342.795436
# 50      685.185692     1069.088510     2186.212050
# 51      400.383513     1191.755001     1667.910912
# 52      423.268899     1407.665266     1984.784647
# 53      573.842145      780.349062     1020.882641
# 54      497.648939      742.635981     1723.942853
# 55      369.133502     1133.652453     1320.622651
# 56      400.047844     1700.704329     2060.252671
# 57      613.067125     1184.287126     1329.256048
# 58      627.531664     1159.676551     1899.352437
# 59      299.587171      686.840512     1512.449018
# 60      597.610726     1324.614726     1342.795436
# 61      685.185692     1069.088510     2186.212050
# 62      400.383513     1191.755001     1667.910912
# 63      423.268899     1407.665266     1984.784647
# 64      573.842145      780.349062     1020.882641
# 65      497.648939      742.635981     1723.942853
# 66      369.133502     1133.652453     1320.622651
# 67      400.047844     1700.704329     2060.252671
# 68      613.067125     1184.287126     1329.256048
# 69      627.531664     1159.676551     1899.352437
# 70      299.587171      686.840512     1512.449018
# 71      597.610726     1324.614726     1342.795436
# 72      685.185692     1069.088510     2186.212050
# 73      400.383513     1191.755001     1667.910912
# 74      423.268899     1407.665266     1984.784647
# 75      573.842145      780.349062     1020.882641
# 76      497.648939      742.635981     1723.942853
# 77      369.133502     1133.652453     1320.622651
# 78      400.047844     1700.704329     2060.252671
# 79      613.067125     1184.287126     1329.256048
# 80      627.531664     1159.676551     1899.352437
# 81      299.587171      686.840512     1512.449018
# 82      597.610726     1324.614726     1342.795436
# 83      685.185692     1069.088510     2186.212050
# 84      400.383513     1191.755001     1667.910912
# 85      423.268899     1407.665266     1984.784647
# 86      573.842145      780.349062     1020.882641
# 87      497.648939      742.635981     1723.942853
# 88      369.133502     1133.652453     1320.622651
# 89      400.047844     1700.704329     2060.252671
# 90      613.067125     1184.287126     1329.256048
# 91      627.531664     1159.676551     1899.352437
# 92      299.587171      686.840512     1512.449018
# 93      597.610726     1324.614726     1342.795436
# 94      685.185692     1069.088510     2186.212050
# 95      400.383513     1191.755001     1667.910912
# 96      423.268899     1407.665266     1984.784647
# 97      573.842145      780.349062     1020.882641
# 98      497.648939      742.635981     1723.942853
# 99      369.133502     1133.652453     1320.622651

# %%
df = pd.read_csv('closest_strategy_trajectories.csv', delimiter=";")
df["penalty"] = False

# %%
import ast
obs = []   
df.obs = df.obs.apply(ast.literal_eval)
df.obs = df.obs.apply(lambda x : obs.append(x))

# %%
df
# Out:
#         obs action  penalty
# 0      None  edc_1    False
# 1      None  edc_2    False
# 2      None  edc_0    False
# 3      None  edc_2    False
# 4      None  edc_0    False
# ...     ...    ...      ...
# 12931  None  edc_0    False
# 12932  None  edc_1    False
# 12933  None  edc_0    False
# 12934  None  edc_1    False
# 12935  None  edc_1    False
#
# [12936 rows x 3 columns]

# %%
df.obs[0][0]
# Out:
# 0.0

# %%
obs = np.array(obs)

# %%
for o in obs:
    o = np.array(o)

# %%
obs.shape
# Out:
# (12936, 9)

# %%
for col in range(obs.shape[1]):
    plt.figure()
    plt.plot(obs[11:,col])
    plt.show

# %%
final_df = pd.DataFrame(np.concatenate([obs, df.action.values[:,np.newaxis], df.penalty.values[:,np.newaxis]],axis=1),
                        columns=["util_0","power_0","dist_0",
                                 "util_1","power_1","dist_1",
                                 "util_2","power_2","dist_2",
                                 "action","penalty"])

# %%
final_df
# Out:
#       util_0   power_0       dist_0 util_1   power_1    dist_1 util_2  \
# 0          0  -3.09091    0.0368665      0  -3.09091  0.442096      0
# 1          0  -3.09091    0.0532525      0  -3.09091   0.74266      0
# 2          0  -3.09091     0.166162      0  -3.09091  0.468935      0
# 3          0  -3.09091     0.173829      0  -3.09091   0.45589      0
# 4          0  -3.09091  3.80097e-06      0  -3.09091  0.205266      0
# ...      ...       ...          ...    ...       ...       ...    ...
# 12931   0.72  0.794066     0.204389   0.76  0.875376  0.407875   0.36
# 12932   0.72  0.794066    0.0534305   0.76  0.875376  0.472893   0.36
# 12933   0.72  0.794066    0.0655608   0.76  0.875376  0.587336   0.36
# 12934   0.72  0.794066     0.145371   0.76  0.875376   0.25483   0.36
# 12935   0.72  0.794066     0.104986   0.76  0.875376   0.23484   0.36
#
#         power_2    dist_2 action penalty
# 0      -3.09091  0.541199  edc_1   False
# 1      -3.09091  0.933237  edc_2   False
# 2      -3.09091  0.545775  edc_0   False
# 3      -3.09091  0.847952  edc_2   False
# 4      -3.09091  0.642876  edc_0   False
# ...         ...       ...    ...     ...
# 12931  0.521459         1  edc_0   False
# 12932  0.521459  0.725278  edc_1   False
# 12933  0.521459  0.893235  edc_0   False
# 12934  0.521459  0.382323  edc_1   False
# 12935  0.521459  0.754977  edc_1   False
#
# [12936 rows x 11 columns]

# %%
final_df.to_csv('closest_strategy_trajectories.csv', index=False)

# %%
final_df.dtypes
# Out:
# util_0     object
# power_0    object
# dist_0     object
# util_1     object
# power_1    object
# dist_1     object
# util_2     object
# power_2    object
# dist_2     object
# action     object
# penalty    object
# dtype: object

# %%
# !ls ../data
# Out:
#  closest_strategy_data_10cars_60seg.csv   'edc_report(transciever_info).csv'
#  closest_strategy_data_50cars_300seg.csv   vanilla_A2C_trajectories.csv
#  closest_strategy_trajectories.csv

# %%
df = pd.read_csv('../data/closest_strategy_data_50cars_300seg.csv', delimiter=";").iloc[11:].reset_index()
df
# Out:
#        index  ap_id edc_id_0        edc_location_0  overall_std_u_0  \
# 0         11   ap_0    edc_0  (950.6207, 777.7721)              0.0
# 1         12   ap_1    edc_0  (950.6207, 777.7721)              0.0
# 2         13   ap_2    edc_0  (950.6207, 777.7721)              0.0
# 3         14   ap_3    edc_0  (950.6207, 777.7721)              0.0
# 4         15   ap_4    edc_0  (950.6207, 777.7721)              0.0
# ...      ...    ...      ...                   ...              ...
# 12920  12931   ap_6    edc_0  (950.6207, 777.7721)            360.0
# 12921  12932   ap_7    edc_0  (950.6207, 777.7721)            360.0
# 12922  12933   ap_8    edc_0  (950.6207, 777.7721)            360.0
# 12923  12934   ap_9    edc_0  (950.6207, 777.7721)            360.0
# 12924  12935  ap_10    edc_0  (950.6207, 777.7721)            360.0
#
#        max_std_u_0  pue_0  power_demand_0  power_consumption_0  it_power_0  \
# 0              500    1.0      441.393776           291.393776  441.393776
# 1              500    1.0      441.393776           291.393776  441.393776
# 2              500    1.0      441.393776           291.393776  441.393776
# 3              500    1.0      441.393776           291.393776  441.393776
# 4              500    1.0      441.393776           291.393776  441.393776
# ...            ...    ...             ...                  ...         ...
# 12920          500    1.0      527.347252           377.347252  527.347252
# 12921          500    1.0      527.347252           377.347252  527.347252
# 12922          500    1.0      527.347252           377.347252  527.347252
# 12923          500    1.0      527.347252           377.347252  527.347252
# 12924          500    1.0      527.347252           377.347252  527.347252
#
#        cooling_power_0  power_generation_0  charging_power_0  energy_stored_0  \
# 0                    0                  50              -100       100.000000
# 1                    0                  50              -100       100.000000
# 2                    0                  50              -100       100.000000
# 3                    0                  50              -100       100.000000
# 4                    0                  50              -100       100.000000
# ...                ...                 ...               ...              ...
# 12920                0                  50              -100        91.697222
# 12921                0                  50              -100        91.697222
# 12922                0                  50              -100        91.697222
# 12923                0                  50              -100        91.697222
# 12924                0                  50              -100        91.697222
#
#        energy_capacity_0 edc_id_1          edc_location_1  overall_std_u_1  \
# 0                    100    edc_1  (1639.6117, 1482.3435)              0.0
# 1                    100    edc_1  (1639.6117, 1482.3435)              0.0
# 2                    100    edc_1  (1639.6117, 1482.3435)              0.0
# 3                    100    edc_1  (1639.6117, 1482.3435)              0.0
# 4                    100    edc_1  (1639.6117, 1482.3435)              0.0
# ...                  ...      ...                     ...              ...
# 12920                100    edc_1  (1639.6117, 1482.3435)            380.0
# 12921                100    edc_1  (1639.6117, 1482.3435)            380.0
# 12922                100    edc_1  (1639.6117, 1482.3435)            380.0
# 12923                100    edc_1  (1639.6117, 1482.3435)            380.0
# 12924                100    edc_1  (1639.6117, 1482.3435)            380.0
#
#        max_std_u_1  pue_1  power_demand_1  power_consumption_1  it_power_1  \
# 0              500    1.0      441.393776           291.393776  441.393776
# 1              500    1.0      441.393776           291.393776  441.393776
# 2              500    1.0      441.393776           291.393776  441.393776
# 3              500    1.0      441.393776           291.393776  441.393776
# 4              500    1.0      441.393776           291.393776  441.393776
# ...            ...    ...             ...                  ...         ...
# 12920          500    1.0      536.291405           386.291405  536.291405
# 12921          500    1.0      536.291405           386.291405  536.291405
# 12922          500    1.0      536.291405           386.291405  536.291405
# 12923          500    1.0      536.291405           386.291405  536.291405
# 12924          500    1.0      536.291405           386.291405  536.291405
#
#        cooling_power_1  power_generation_1  charging_power_1  energy_stored_1  \
# 0                    0                  50              -100            100.0
# 1                    0                  50              -100            100.0
# 2                    0                  50              -100            100.0
# 3                    0                  50              -100            100.0
# 4                    0                  50              -100            100.0
# ...                ...                 ...               ...              ...
# 12920                0                  50              -100             91.8
# 12921                0                  50              -100             91.8
# 12922                0                  50              -100             91.8
# 12923                0                  50              -100             91.8
# 12924                0                  50              -100             91.8
#
#        energy_capacity_1 edc_id_2         edc_location_2  overall_std_u_2  \
# 0                    100    edc_2  (802.2772, 2478.5847)              0.0
# 1                    100    edc_2  (802.2772, 2478.5847)              0.0
# 2                    100    edc_2  (802.2772, 2478.5847)              0.0
# 3                    100    edc_2  (802.2772, 2478.5847)              0.0
# 4                    100    edc_2  (802.2772, 2478.5847)              0.0
# ...                  ...      ...                    ...              ...
# 12920                100    edc_2  (802.2772, 2478.5847)            180.0
# 12921                100    edc_2  (802.2772, 2478.5847)            180.0
# 12922                100    edc_2  (802.2772, 2478.5847)            180.0
# 12923                100    edc_2  (802.2772, 2478.5847)            180.0
# 12924                100    edc_2  (802.2772, 2478.5847)            180.0
#
#        max_std_u_2  pue_2  power_demand_2  power_consumption_2  it_power_2  \
# 0              500    1.0      441.393776           291.393776  441.393776
# 1              500    1.0      441.393776           291.393776  441.393776
# 2              500    1.0      441.393776           291.393776  441.393776
# 3              500    1.0      441.393776           291.393776  441.393776
# 4              500    1.0      441.393776           291.393776  441.393776
# ...            ...    ...             ...                  ...         ...
# 12920          500    1.0      497.360474           347.360474  497.360474
# 12921          500    1.0      497.360474           347.360474  497.360474
# 12922          500    1.0      497.360474           347.360474  497.360474
# 12923          500    1.0      497.360474           347.360474  497.360474
# 12924          500    1.0      497.360474           347.360474  497.360474
#
#        cooling_power_2  power_generation_2  charging_power_2  energy_stored_2  \
# 0                    0                  50              -100       100.000000
# 1                    0                  50              -100       100.000000
# 2                    0                  50              -100       100.000000
# 3                    0                  50              -100       100.000000
# 4                    0                  50              -100       100.000000
# ...                ...                 ...               ...              ...
# 12920                0                  50              -100        91.697222
# 12921                0                  50              -100        91.697222
# 12922                0                  50              -100        91.697222
# 12923                0                  50              -100        91.697222
# 12924                0                  50              -100        91.697222
#
#        energy_capacity_2  edc_distance_0  edc_distance_1  edc_distance_2  \
# 0                    100      369.133502     1133.652453     1320.622651
# 1                    100      400.047844     1700.704329     2060.252671
# 2                    100      613.067125     1184.287126     1329.256048
# 3                    100      627.531664     1159.676551     1899.352437
# 4                    100      299.587171      686.840512     1512.449018
# ...                  ...             ...             ...             ...
# 12920                100      685.185692     1069.088510     2186.212050
# 12921                100      400.383513     1191.755001     1667.910912
# 12922                100      423.268899     1407.665266     1984.784647
# 12923                100      573.842145      780.349062     1020.882641
# 12924                100      497.648939      742.635981     1723.942853
#
#       action
# 0      edc_1
# 1      edc_2
# 2      edc_0
# 3      edc_2
# 4      edc_0
# ...      ...
# 12920  edc_0
# 12921  edc_1
# 12922  edc_0
# 12923  edc_1
# 12924  edc_1
#
# [12925 rows x 45 columns]

# %%
total_power = np.concatenate([df["power_consumption_0"],df["power_consumption_1"],df["power_consumption_2"]], axis=0)
print("Power mean: {} std: {}".format(np.mean(total_power), np.std(total_power)))
# Out:
# Power mean: 361.19220148397676 std: 25.892223947598993

# %%
def overall_mean_and_std(col):
    total_np = np.concatenate([df[col+"_0"],df[col+"_1"],df[col+"_2"]])
    print("Power mean: {} std: {}".format(np.mean(total_np), np.std(total_np)))
